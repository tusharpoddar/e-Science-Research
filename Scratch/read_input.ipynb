# %%
import numpy as np

# %%
a = np.load('readnumpy.npy')

# %%
print(a)
# Out:
# [[[-4.60441965 -4.6045388  -4.60474968 ... -4.5987267  -4.60019588
#    -4.59890431]
#   [-4.6044059  -4.60431802 -4.60450667 ... -4.59950011 -4.59831331
#    -4.60026179]
#   [-4.60408656 -4.60438709 -4.60421756 ... -4.60105617 -4.60038925
#    -4.60140355]
#   ...
#   [-4.40531052 -4.46780836 -4.45009653 ... -0.75850953 -0.91832766
#    -0.57355519]
#   [-4.55184584 -4.5615784  -4.49724933 ... -1.08360722 -0.46956434
#    -0.34813408]
#   [-4.51785529 -4.53703963 -4.58434832 ... -0.82719114 -0.30334259
#    -0.32659489]]
#
#  [[-4.47343962 -4.50993748 -4.45344459 ... -0.68862477 -0.06947865
#    -0.46615705]
#   [-4.50244982 -4.47506344 -4.4526152  ... -1.01905827 -0.76721705
#    -0.4509051 ]
#   [-4.52222009 -4.53760227 -4.51827117 ... -0.21439285 -0.0212088
#    -0.2716569 ]
#   ...
#   [-4.46091517 -4.49281118 -4.50790185 ... -1.00876715 -0.74390702
#    -0.69899111]
#   [-4.57450696 -4.53574352 -4.50983675 ... -0.5258551  -0.30555701
#    -0.28830897]
# ...

# %%
a.shape
# Out:
# (60, 96, 64)

# %%
for x in (0,59):
    print(a[x])
# Out:
# [[-4.60441965 -4.6045388  -4.60474968 ... -4.5987267  -4.60019588
#   -4.59890431]
#  [-4.6044059  -4.60431802 -4.60450667 ... -4.59950011 -4.59831331
#   -4.60026179]
#  [-4.60408656 -4.60438709 -4.60421756 ... -4.60105617 -4.60038925
#   -4.60140355]
#  ...
#  [-4.40531052 -4.46780836 -4.45009653 ... -0.75850953 -0.91832766
#   -0.57355519]
#  [-4.55184584 -4.5615784  -4.49724933 ... -1.08360722 -0.46956434
#   -0.34813408]
#  [-4.51785529 -4.53703963 -4.58434832 ... -0.82719114 -0.30334259
#   -0.32659489]]
# [[-4.49669051 -4.46477247 -4.43538874 ... -0.33113876 -0.30726187
#   -0.54954757]
#  [-4.52557321 -4.48310371 -4.435789   ... -0.15778666 -0.35439639
#   -0.35631893]
#  [-4.52822314 -4.49220023 -4.47708738 ... -0.11611995 -0.32331862
#    0.07745172]
#  ...
#  [-4.50977764 -4.48661937 -4.52506904 ... -0.3356591  -0.37382722
#    0.36110995]
#  [-4.54397614 -4.50365095 -4.48627512 ... -0.15234591  0.16001363
#    0.35218249]
# ...

# %%
#now plotting the things on the graph
import matplotlib.pyplot as plt
plt.figure(figsize = (100,10))\
#the .T is for the traspose thing to rotate the axis of the x and the y 
plt.imshow(a[8].T)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a6613cb45af2> in <module>
#       3 plt.figure(figsize = (100,10))\
#       4 #the .T is for the traspose thing to rotate the axis of the x and the y
# ----> 5 plt.imshow(a[8].T)
#
# NameError: name 'a' is not defined

# %%
time = 0.96/96

# %%
print(time)
# Out:
# 0.01

# %%
# trying to find the 2 d array of the data with the frequenct and the timestap in the same thing 
# the logic is that the sape of the numpy array is 60 into 96 into 64. Here 96 is the time, frequency is 64 and
# there are 60 such records of this information 
import array 
array = [] 
# empty array 
print(array)
# Out:
# []

# %%
# how do i find the initial timestamp - the initial value in which we add stuff to 
for x in (0,59):
    array = [0]
    array.append()
